# %%
from sklearn import tree
import pandas as pd
import os

# %%
election = pd.read_csv(os.path.join("..", "Resources", "data_retrieval.csv"))
election.head()
# Out:
#   st_abbrev  district party  Total_Receipt  Total_Disbursement  \
# 0        AK         0   REP      1041380.0           1159940.0
# 1        AL         1   REP      1325140.0            662806.0
# 2        AL         2   REP      2506890.0           2100810.0
# 3        AL         3   REP      1219670.0            857764.0
# 4        AL         4   REP      1487010.0            853026.0
#
#    Cash_On_Hand_COP  Debt_Owed_By_Committee  Individual_Itemized_Contribution  \
# 0          151165.0                     0.0                          513967.0
# 1         1108650.0                     0.0                          264612.0
# 2          451536.0                     0.0                          741087.0
# 3          887448.0                     0.0                          450890.0
# 4         1099490.0                     0.0                          430365.0
#
#    Individual_Unitemized_Contribution  Individual_Contribution     ...      \
# ...

# %%
df = election.drop(['id','st_abbrev', 'district', "Industries_not_classified4", "state_dist"], axis=1)

# %%
df.head()
# Out:
#   party  Total_Receipt  Total_Disbursement  Cash_On_Hand_COP  \
# 0   REP      1041380.0           1159940.0          151165.0
# 1   REP      1325140.0            662806.0         1108650.0
# 2   REP      2506890.0           2100810.0          451536.0
# 3   REP      1219670.0            857764.0          887448.0
# 4   REP      1487010.0            853026.0         1099490.0
#
#    Debt_Owed_By_Committee  Individual_Itemized_Contribution  \
# 0                     0.0                          513967.0
# 1                     0.0                          264612.0
# 2                     0.0                          741087.0
# 3                     0.0                          450890.0
# 4                     0.0                          430365.0
#
#    Individual_Unitemized_Contribution  Individual_Contribution  \
# 0                             41063.9                 555031.0
# 1                             10105.0                 274717.0
# ...

# %%
target = df["party"]
target_names = ["negative", "positive"]

# %%
data = df.drop("party", axis=1)
feature_names = data.columns
data.head()
# Out:
#    Total_Receipt  Total_Disbursement  Cash_On_Hand_COP  \
# 0      1041380.0           1159940.0          151165.0
# 1      1325140.0            662806.0         1108650.0
# 2      2506890.0           2100810.0          451536.0
# 3      1219670.0            857764.0          887448.0
# 4      1487010.0            853026.0         1099490.0
#
#    Debt_Owed_By_Committee  Individual_Itemized_Contribution  \
# 0                     0.0                          513967.0
# 1                     0.0                          264612.0
# 2                     0.0                          741087.0
# 3                     0.0                          450890.0
# 4                     0.0                          430365.0
#
#    Individual_Unitemized_Contribution  Individual_Contribution  \
# 0                             41063.9                 555031.0
# 1                             10105.0                 274717.0
# 2                             46129.8                 787217.0
# ...

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(data, target, random_state=42)

# %%
clf = tree.DecisionTreeClassifier()
clf = clf.fit(X_train, y_train)
clf.score(X_test, y_test)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-72-919dfd680ef1> in <module>()
#       1 clf = tree.DecisionTreeClassifier()
# ----> 2 clf = clf.fit(X_train, y_train)
#       3 clf.score(X_test, y_test)
#
# /anaconda3/envs/PythonData/lib/python3.6/site-packages/sklearn/tree/tree.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     788             sample_weight=sample_weight,
#     789             check_input=check_input,
# --> 790             X_idx_sorted=X_idx_sorted)
#     791         return self
#     792
#
# /anaconda3/envs/PythonData/lib/python3.6/site-packages/sklearn/tree/tree.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     114         random_state = check_random_state(self.random_state)
#     115         if check_input:
# --> 116             X = check_array(X, dtype=DTYPE, accept_sparse="csc")
# ...

# %%
from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier(n_estimators=20)
rf = rf.fit(X_train, y_train)
rf.score(X_test, y_test)
# Out:
# 0.8256880733944955

# %%
 sorted(zip(rf.feature_importances_, feature_names), reverse=True)
# Out:
# [(0.047907341751844315, '250_to_399'),
#  (0.04515776937521011, '500_to_999a'),
#  (0.04266156567569025, 'Housing_units_without_a_mortgage'),
#  (0.037970116780786066, '1_500_to_1_999b'),
#  (0.023685984307507173, 'Mining__quarrying__and_oil_and_gas_extraction1'),
#  (0.022964961044644506, 'Public_transportation_excluding_taxicab'),
#  (0.021056654970596368, 'Irish'),
#  (0.019006866730144106, 'Less_than_50_000'),
#  (0.018313353665120165, 'ScotchIrish'),
#  (0.017954801373800035, 'Agriculture__forestry__fishing_and_hunting1'),
#  (0.01686848019637896, 'Median_dollars2'),
#  (0.016113214087596632, 'White'),
#  (0.01605236057002089,
#   'Agriculture__forestry__fishing_and_hunting__and_mining'),
#  (0.015397615765094214, '2_500_to_2_999b'),
#  (0.01532088523993141, 'Foreign_born'),
#  (0.015138019672333403, '50_000_to_99_999'),
#  (0.01499529732662214, 'Utilities3'),
#  (0.014448613253307898, 'American'),
#  (0.013174916645598573, 'Graduate_or_professional_degree'),
# ...

# %%
# Out:
# [(0.058985033306369936, 'Public_transportation_excluding_taxicab'), (0.05363083135079348, 'Foreign_born'), (0.0377943902953491, 'Born_in_United_States'), (0.03170276382718641, 'Less_than_250'), (0.02990366159470927, '400_to_599'), (0.022142544066125966, '500_to_999a'), (0.021766116909306528, 'Housing_units_without_a_mortgage'), (0.019541834681959046, 'American'), (0.017272436210601615, 'Agriculture__forestry__fishing_and_hunting2'), (0.016765124456656972, '1_000_to_1_499a'), (0.016476507614901503, '50_000_to_74_999'), (0.01635545048961632, '50_000_to_99_999'), (0.01624786684572141, 'Civilian_veterans'), (0.01455194320512294, 'Less_than_500a'), (0.014469412478834376, '2_500_to_2_999a'), (0.014147755160758302, 'Occupied_units_paying_rent'), (0.013577819313344324, 'Renteroccupied'), (0.012669475287774012, 'Dutch'), (0.012534509859784113, 'ScotchIrish'), (0.011601891561221387, 'Service_occupations'), (0.010886445281122776, 'Educational_services1'), (0.010575143204451822, 'Educational_ser
# ...

# %%
#First try with data_retrieval_clean data
(0.06944683206013694, 'Native'),
 (0.06778545248736681, 'Housing_units_without_a_mortgage'),
 (0.050590582802684705, 'Public_transportation_excluding_taxicab'),
 (0.04663181036547453, 'Foreign_born'),
 (0.04019098000469825, 'Owneroccupied'),
 (0.0257764734000736, 'Less_than_50_000'),
 (0.02407910813952162, 'Mining__quarrying__and_oil_and_gas_extraction3'),
 (0.02358109813657187, '50_000_to_99_999'),
 (0.019383439610887194, '100_000_to_149_999a'),
 (0.01707200663316665, '250_to_399'),
 (0.016187125862931424, 'With_a_disability3'),
 (0.015597152867403583, 'Arab'),
 (0.012652051821809101, 'German'),
 (0.012108126027063525, 'Scottish'),
 (0.011848994143518959, 'Some_other_race'),
 (0.01182472992222696, 'Dutch'),
 (0.01158744209442443, 'Irish'),
 (0.011030210901114768, '150_000_to_199_999'),
 (0.010920211307753605, 'American'),

# %%
# second run with data_retrieval_clean data
(0.06140897554225361, 'Public_transportation_excluding_taxicab'),
 (0.05564804927143511, '1_500_to_1_999b'),
 (0.04986879648029331, '500_to_999a'),
 (0.04641224812493576, 'Median_dollars4'),
 (0.04117606192269824, 'Native'),
 (0.02914198592070656, 'Civilian_veterans'),
 (0.02816764754041008, 'Foreign_born'),
 (0.02196962354847624, 'Utilities3'),
 (0.01932114240686124, 'White'),
 (0.017436264617090042, 'Less_than_250'),
 (0.016709011652123476, 'ScotchIrish'),
 (0.015632189495193835, 'Renteroccupied'),
 (0.014730613243925657, 'Median_dollars1'),
 (0.013009557972679917, 'Less_than_50_000'),
 (0.0128419682648537, 'State_of_residence'),
 (0.01178701469422252, 'Professional__scientific__and_technical_services2'),
 (0.011691944646157174, 'Mining__quarrying__and_oil_and_gas_extraction2'),
 (0.010354694193243235, '250_to_399'),
 (0.009837569380230409, 'Median_dollars3'),
 (0.009830284750372158, '3_000_or_more2'),

# %%
# third run with data_retrieval_clean data
0.058985033306369936, 'Public_transportation_excluding_taxicab'),
 (0.05363083135079348, 'Foreign_born'),
 (0.0377943902953491, 'Born_in_United_States'),
 (0.03170276382718641, 'Less_than_250'),
 (0.02990366159470927, '400_to_599'),
 (0.022142544066125966, '500_to_999a'),
 (0.021766116909306528, 'Housing_units_without_a_mortgage'),
 (0.019541834681959046, 'American'),
 (0.017272436210601615, 'Agriculture__forestry__fishing_and_hunting2'),
 (0.016765124456656972, '1_000_to_1_499a'),
 (0.016476507614901503, '50_000_to_74_999'),
 (0.01635545048961632, '50_000_to_99_999'),
 (0.01624786684572141, 'Civilian_veterans'),
 (0.01455194320512294, 'Less_than_500a'),
 (0.014469412478834376, '2_500_to_2_999a'),
 (0.014147755160758302, 'Occupied_units_paying_rent'),
 (0.013577819313344324, 'Renteroccupied'),
 (0.012669475287774012, 'Dutch'),
 (0.012534509859784113, 'ScotchIrish'),

# %%
# fourth run with data_retrieval_clean data
(0.05443605263554082,
  'Agriculture__forestry__fishing_and_hunting__and_mining'),
 (0.05331800911776474, 'Public_transportation_excluding_taxicab'),
 (0.043511165934758046, '100_000_to_149_999a'),
 (0.041478952411772005, '250_to_399'),
 (0.036209294104134176, 'American'),
 (0.03291548319024016, '50_000_to_99_999'),
 (0.03136532423900623, 'Born_in_United_States'),
 (0.024699234868376167, 'Irish'),
 (0.02316758927604264, 'Native'),
 (0.02094346655578025, '150_000_to_199_999'),
 (0.02068622130895132, 'Agriculture__forestry__fishing_and_hunting1'),
 (0.017511618212175336, 'Mining__quarrying__and_oil_and_gas_extraction3'),
 (0.015991304652452097, 'Graduate_or_professional_degree'),
 (0.015544767355850374, 'Housing_units_without_a_mortgage'),
 (0.015374821157004958, 'Less_than_500a'),
 (0.015315536150772505, '400_to_599'),
 (0.01489795815184081, 'Educational_services3'),
 (0.013236694535956273, '3_000_or_more2'),
 (0.013215176415903954, 'Owneroccupied'),

# %%
# fith run with data_retrieval_clean data
(0.047907341751844315, '250_to_399'),
 (0.04515776937521011, '500_to_999a'),
 (0.04266156567569025, 'Housing_units_without_a_mortgage'),
 (0.037970116780786066, '1_500_to_1_999b'),
 (0.023685984307507173, 'Mining__quarrying__and_oil_and_gas_extraction1'),
 (0.022964961044644506, 'Public_transportation_excluding_taxicab'),
 (0.021056654970596368, 'Irish'),
 (0.019006866730144106, 'Less_than_50_000'),
 (0.018313353665120165, 'ScotchIrish'),
 (0.017954801373800035, 'Agriculture__forestry__fishing_and_hunting1'),
 (0.01686848019637896, 'Median_dollars2'),
 (0.016113214087596632, 'White'),
 (0.01605236057002089,
  'Agriculture__forestry__fishing_and_hunting__and_mining'),
 (0.015397615765094214, '2_500_to_2_999b'),
 (0.01532088523993141, 'Foreign_born'),
 (0.015138019672333403, '50_000_to_99_999'),
 (0.01499529732662214, 'Utilities3'),
 (0.014448613253307898, 'American'),
